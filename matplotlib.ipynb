# %% [markdown]
# <a href="https://colab.research.google.com/github/GANESH300118/Python_New/blob/Module_4/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# # Plotting

# %%
#1
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(xpoints, ypoints)
plt.show()

# %%
#2
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
#3
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(xpoints, ypoints)
plt.show()

# %%
#4
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints)
plt.show()

# %% [markdown]
# # Markers

# %%
#1
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
#2
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, marker = '*')
plt.show()

# %%
#3
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, 'o:r')
plt.show()

# %%
#4
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
#5
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
#6
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
#7
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %%
#8
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %%
#9
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()

# %% [markdown]
# # line graph

# %%
#1
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(xpoints, ypoints)                              
plt.show()

# %%
#2
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
#3
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, ls = ':')
plt.show()

# %%
#4
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, color = 'r')
plt.show()

# %%
#5
import matplotlib.pyplot as plt
import numpy as np
y1 = np.array([80,81,83,85,87,88,89,92,99])
y2 = np.array([23,45,98,87,60,66,98,70,99])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
#6
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# # Piegragh

# %%
#1
import matplotlib.pyplot as plt
import numpy as np
y = np.array([80,81,83,85,87,88,89,92,99])
plt.pie(y)
plt.show()

# %%
#2
import matplotlib.pyplot as plt
import numpy as np
y = np.array([80,81,83,85,87,88,89,92,99])
mylabels=['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH']
plt.pie(y, labels = mylabels)
plt.show()

# %%
#3
import matplotlib.pyplot as plt
import numpy as np
y = np.array([80,81,83,85,87,88,89,92,99])
mylabels=['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH']
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
#4
import matplotlib.pyplot as plt
import numpy as np
y = np.array([80,81,83,85,87,88,89,92,99])
mylabels=['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH']
myexplode = [0.2, 0, 0, 0.3,0,0,0,0,0]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
#5
import matplotlib.pyplot as plt
import numpy as np
y = np.array([80,81,83,85,87,88,89,92,99])
mylabels=['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH']
myexplode = [0.2, 0, 0, 0,0,0,0,0,0]
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
#6
import matplotlib.pyplot as plt
import numpy as np
y = np.array([80,81,83,85,87,88,89,92,99])
mylabels=['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH']
colours=['red','hotpink','blue','green','violet','orange','indigo','purple','black',]
plt.pie(y, labels = mylabels, colors = colours)
plt.show()

# %%
#7
import matplotlib.pyplot as plt
import numpy as np
y = np.array([80,81,83,85,87,88,89,92,99])
mylabels=['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH']
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
#8
import matplotlib.pyplot as plt
import numpy as np
y = np.array([80,81,83,85,87,88,89,92,99])
mylabels=['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH']
plt.pie(y, labels = mylabels)
plt.legend(title = "Marks")
plt.show()

# %%
#9import matplotlib.pyplot as plt
import numpy as np
y = np.array([80,81,83,85,87,88,89,92,99])
mylabels=['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH']
plt.pie(y,labels=mylabels)
plt.legend()
plt.show()

# %%
#10
import matplotlib.pyplot as plt
import numpy as np
y = np.array([80,81,83,85,87,88,89,92,99])
mylabels=['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH']
colours=['red','hotpink','blue','green','violet','orange','indigo','purple','black',]
plt.pie(y,labels=mylabels,colors=colours)
plt.legend()
plt.show()

# %% [markdown]
# # Histograms

# %%
#1
import matplotlib.pyplot as plt
import numpy as np
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()

# %%
#2
import matplotlib.pyplot as plt
import numpy as np
x = np.random.normal(800, 100, 300)
plt.hist(x)
plt.show()

# %% [markdown]
# # Bars

# %%
#1
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.bar(x,y)
plt.show()

# %%
#2
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.barh(x,y)
plt.show()

# %%
#3
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
# plt.barh(x,y)
plt.bar(x, y, width = 0.1)
plt.show()

# %%
#4
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.bar(x, y, color = "red")
plt.show()

# %%
#5
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
#6
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.barh(x, y, height = 0.1)
plt.show()

# %%
#7
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.bar(x, y, color = "hotpink")
plt.show()

# %% [markdown]
# # scatter

# %%
#1
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.scatter(x, y)
plt.show()

# %%
#2
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.scatter(x,y,color='hotpink')
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([90,90,87,89,90,91,96,94,99])
plt.scatter(x,y,color='green')
plt.show()

# %%
#3
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
colours=np.array(["pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x, y, c=colours)
plt.show()

# %%
#4
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.show()

# %%
#5
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x, y, c=colors, cmap='viridis')
plt.show()

# %% [markdown]
# # Subplot

# %%
#1
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 1)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 2)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 3)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 4)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 5)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 6)
plt.plot(x,y)
plt.show()

# %%
#2
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("MY SHOP")
plt.show()

# %%
#3
import matplotlib.pyplot as plt
import numpy as np
#Plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")
#Plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.show()

# %%
#4
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array(['Clad','Math1','Math2','Vedc'])
y = np.array([80,81,83,85])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Person-1")
#plot 2:
x = np.array(['Clad','Math1','Math2','Vedc'])
y = np.array([90,90,87,89])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Person-2")
plt.suptitle("MARKS")
plt.show()

# %%
#5
import matplotlib.pyplot as plt
import numpy as np
#Plot 1:
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.subplot(2,1,1)
plt.plot(x,y)
# plt.title("Person-1")
#Plot 2:
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([90,90,87,89,90,91,96,94,99])
plt.subplot(2,1,2)
plt.plot(x,y)
# plt.title("Person-2")
plt.suptitle("MARKS")
plt.show()

# %% [markdown]
# # Grids

# %%
#1
import numpy as np
import matplotlib.pyplot as plt
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.title("MY MARKS")
plt.xlabel("SUBJECTS")
plt.ylabel("Marks")
plt.plot(x, y)
plt.grid(axis = 'y')
plt.show()

# %%
#2
import numpy as np
import matplotlib.pyplot as plt
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.title("MY MARKS")
plt.xlabel("SUBJECTS")
plt.ylabel("Marks")
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
#3
import numpy as np
import matplotlib.pyplot as plt
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.title("MY MARKS")
plt.xlabel("SUBJECTS")
plt.ylabel("Marks")
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
#4
import numpy as np
import matplotlib.pyplot as plt
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.title("MY MARKS")
plt.xlabel("SUBJECTS")
plt.ylabel("Marks")
plt.plot(x, y)
plt.grid()
plt.show()

# %% [markdown]
# # lables

# %%
#1
import numpy as np
import matplotlib.pyplot as plt
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(x, y)
plt.xlabel("MY COURSES")
plt.ylabel("MARKES")
plt.show()

# %%
#2
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("SEM MARKS")
plt.xlabel("MY COURSES")
plt.ylabel("MARKES")
plt.show()

# %%
#3
import numpy as np
import matplotlib.pyplot as plt
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title("SEM MARKS")
plt.xlabel("MY COURSES")
plt.ylabel("MARKES")
plt.plot(x, y)
plt.show()

# %%
#4
import numpy as np
import matplotlib.pyplot as plt
x = np.array(['Clad','Math1','Math2','Vedc','Phys','Lang','CSEN1','CSEN2','MECH'])
y = np.array([80,81,83,85,87,88,89,92,99])
plt.plot(x, y)
plt.title("SEM MARKS")
plt.xlabel("MY COURSES")
plt.ylabel("MARKES")
plt.show()

# %%
#1
import matplotlib.pyplot as p
import numpy as np
x=np.array([3,8,1,10])
y=np.array([0,1,2,3])
p.plot(y,x,'o:r')
p.show()

# %%
#2
import matplotlib.pyplot as p
import numpy as np
y=np.array([50,45,37,22])
mylables=['Python','Maths','English','chemistry']
colors=['Blue','Red','Green','orange']
myexplode=[0.3,0,0,0]
p.pie(y,labels=mylables,colors=colors,explode=myexplode)
p.show( )

# %%
import matplotlib.pyplot as plt
import numpy as p
y=p.array([50,45,37,22])
colors=['Blue','Red','Green','Orange']
mylabels=['CSE','ECE','Civil','Mech']
plt.pie(y,labels=mylables,colors=colors)
plt.legend()
plt.show( )

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.3.5
